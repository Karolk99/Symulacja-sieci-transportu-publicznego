# %%
import pandas as pd
import matplotlib
from utils import *

# %% [markdown]
# ## One line

# %%
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/one_line/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/one_line/context_trace_log01.csv", index_col=False)
buses_ids = ["1", "2", "3", "4", "5"]
stops_ids = ["A", "B"]

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_buses(data)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"])
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/Results.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/Results.ipynb#X62sZmlsZQ%3D%3D?line=0'>1</a> data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
# ...

# %% [markdown]
# ## two line

# %% [markdown]
# ### normal

# %%
buses_ids = [str(number) for number in range(1, 215)]
stops_ids = ["A", "B", "C", "D", "E"]
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/two_lines/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/two_lines/context_trace_log01.csv", index_col=False)

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_stops(data, stops_ids)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"], ylabel="number of people")
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# <AxesSubplot:ylabel='number of people'>

# %% [markdown]
# ### traffic

# %%
buses_ids = [str(number) for number in range(1, 215)]
stops_ids = ["A", "B", "C", "D", "E"]
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/two_lines_traffic/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/two_lines_traffic/context_trace_log01.csv", index_col=False)

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_stops(data, stops_ids)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"], ylabel="number of people")
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# <AxesSubplot:ylabel='number of people'>

# %% [markdown]
# ### unbalanced

# %%
buses_ids = [str(number) for number in range(1, 215)]
stops_ids = ["A", "B", "C", "D", "E"]
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/two_lines_unbalanced/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/two_lines_unbalanced/context_trace_log01.csv", index_col=False)

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_stops(data, stops_ids)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"], ylabel="number of people")
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# <AxesSubplot:ylabel='number of people'>

# %% [markdown]
# ## big traffic

# %% [markdown]
# ### normal

# %%
buses_ids = [str(number) for number in range(1, 608)]
stops_ids = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/big_traffic/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/big_traffic/context_trace_log01.csv", index_col=False)

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_stops(data, stops_ids)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"], ylabel="number of people")
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# <AxesSubplot:ylabel='number of people'>

# %% [markdown]
# ### bad

# %%
buses_ids = [str(number) for number in range(1, 608)]
stops_ids = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/bit_traffic_bad/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/bit_traffic_bad/context_trace_log01.csv", index_col=False)

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_stops(data, stops_ids)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"], ylabel="number of people")
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# <AxesSubplot:ylabel='number of people'>

# %% [markdown]
# ### unbalanced

# %%
buses_ids = [str(number) for number in range(1, 608)]
stops_ids = ["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"]
symulation_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/big_traffic_unbalanced/trace_log01.csv", index_col=False)
entity_state = pd.read_csv("/Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/simulation_components/logs/results/big_traffic_unbalanced/context_trace_log01.csv", index_col=False)

# %%
data = prepare_data(entity_state.loc[entity_state['type'] == "Bus"], buses_ids)
plot_buses(data)
data = prepare_data(entity_state.loc[entity_state['type'] == "BusStop"], stops_ids)
plot_stops(data, stops_ids)
symulation_state.plot(y=["passengers", "waiting_psg", "commuting_psg"], ylabel="number of people")
# Out:
# /Users/karolkonkol/Documents/Symulacja-sieci-transportu-publicznego/wyniki/utils.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=df['timestamp'].map(toInt)
# <AxesSubplot:ylabel='number of people'>
